# %% [markdown]
# # 40% interval, Normal distribution

# %%
import Test_main as Tm
Tm.online_test_out(0.4, 'normal40')
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99650070e-01, 9.99800040e-05, 1.58116709e-04, 8.42509054e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63302898e-01, 0.00000000e+00])]
# ['action:', array([9.528602e-06, 1.000000e+00, 1.000000e+00, 9.999999e-01,
#        9.501462e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99570086e-01, 3.99920016e-05, 2.12961575e-04, 1.34242098e-04,
#        1.02870748e-08, 3.99920016e-05, 9.23873489e-01, 0.00000000e+00])]
# ['action:', array([0.00268769, 0.9999995 , 1.        , 1.        , 0.9895856 ],
#       dtype=float32)]
# ['time:', 2, 'state:', array([9.99540092e-01, 1.99960008e-05, 2.14502764e-04, 1.62109296e-04,
#        2.66781446e-08, 6.99860028e-05, 8.84703117e-01, 0.00000000e+00])]
# ['action:', array([0.00114165, 0.99999917, 1.        , 1.        , 0.98272103],
#       dtype=float32)]
# ['time:', 3, 'state:', array([9.99520096e-01, 9.99800040e-06, 1.95792963e-04, 1.76439898e-04,
# ...

# %% [markdown]
# # 40% interval, Gamma distribution

# %%
import Test_main as Tm
Tm.online_test_out(0.4, 'gamma40')
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99660068e-01, 8.99820036e-05, 1.58674083e-04, 7.89691416e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63302898e-01, 0.00000000e+00])]
# ['action:', array([9.528602e-06, 1.000000e+00, 1.000000e+00, 9.999999e-01,
#        9.501462e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99580084e-01, 3.99920016e-05, 2.08765826e-04, 1.23813411e-04,
#        9.64217822e-09, 3.99920016e-05, 9.23700715e-01, 0.00000000e+00])]
# ['action:', array([0.00393865, 0.9999994 , 1.        , 1.        , 0.9921875 ],
#       dtype=float32)]
# ['time:', 2, 'state:', array([9.99550090e-01, 1.99960008e-05, 2.06491067e-04, 1.47959228e-04,
#        2.47599111e-08, 6.99860028e-05, 8.84478432e-01, 0.00000000e+00])]
# ['action:', array([0.00146481, 0.99999905, 1.        , 1.        , 0.98405844],
#       dtype=float32)]
# ['time:', 3, 'state:', array([9.99530094e-01, 9.99800040e-06, 1.86252532e-04, 1.60046080e-04,
# ...
