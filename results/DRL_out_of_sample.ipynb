# %% [markdown]
# # 20% interval, 10% Bias

# %%
import Test_offline as To
To.offline_test_out(0.2, 0.1)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99650070e-01, 8.99820036e-05, 1.72089951e-04, 6.89375208e-05,
#        0.00000000e+00, 9.99800040e-06, 9.60384156e-01, 0.00000000e+00])]
# ['action:', array([2.1656643e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99580084e-01, 3.99920016e-05, 2.14413749e-04, 1.02002464e-04,
#        8.41728736e-09, 2.99940012e-05, 9.20451935e-01, 0.00000000e+00])]
# ['action:', array([1.6143687e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99550090e-01, 1.99960008e-05, 2.10079817e-04, 1.18325027e-04,
#        2.08718121e-08, 4.99900020e-05, 8.80391537e-01, 0.00000000e+00])]
# ['action:', array([1.1976508e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99540092e-01, 9.99800040e-06, 1.90647316e-04, 1.25934698e-04,
# ...

# %% [markdown]
# # 20% interval, 20% Bias

# %%
import Test_offline as To
To.offline_test_out(0.2, 0.2)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99650070e-01, 8.99820036e-05, 1.73590382e-04, 6.49984480e-05,
#        0.00000000e+00, 9.99800040e-06, 9.60384156e-01, 0.00000000e+00])]
# ['action:', array([2.1656643e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99580084e-01, 3.99920016e-05, 2.15607057e-04, 9.43294997e-05,
#        7.93632566e-09, 2.99940012e-05, 9.20463893e-01, 0.00000000e+00])]
# ['action:', array([1.6143842e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99550090e-01, 1.99960008e-05, 2.11445582e-04, 1.07961468e-04,
#        1.94539796e-08, 4.99900020e-05, 8.80427851e-01, 0.00000000e+00])]
# ['action:', array([1.1977833e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99540092e-01, 9.99800040e-06, 1.92640279e-04, 1.13884287e-04,
# ...

# %% [markdown]
# # 20% interval, 30% Bias

# %%
import Test_offline as To
To.offline_test_out(0.2, 0.3)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99650070e-01, 8.99820036e-05, 1.74789562e-04, 5.28789421e-05,
#        0.00000000e+00, 9.99800040e-06, 9.60384156e-01, 0.00000000e+00])]
# ['action:', array([2.1656643e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99580084e-01, 3.99920016e-05, 2.04669393e-04, 7.36003513e-05,
#        6.45653116e-09, 2.99940012e-05, 9.20502786e-01, 0.00000000e+00])]
# ['action:', array([1.6144488e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99550090e-01, 1.99960008e-05, 1.94309133e-04, 8.26841985e-05,
#        1.54431512e-08, 4.99900020e-05, 8.80541266e-01, 0.00000000e+00])]
# ['action:', array([1.1982448e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99540092e-01, 9.99800040e-06, 1.74426889e-04, 8.66664289e-05,
# ...

# %% [markdown]
# # 40% interval, 10% Bias

# %%
import Test_offline as To
To.offline_test_out(0.4, 0.1)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99660068e-01, 8.99820036e-05, 1.63205531e-04, 6.49984403e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63872405e-01, 0.00000000e+00])]
# ['action:', array([1.0930979e-05, 1.0000000e+00, 1.0000000e+00, 9.9999988e-01,
#        9.4012624e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99590082e-01, 3.99920016e-05, 2.11184514e-04, 9.69172561e-05,
#        7.93630956e-09, 2.99940012e-05, 9.27445852e-01, 0.00000000e+00])]
# ['action:', array([6.4534538e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012487e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99560088e-01, 1.99960008e-05, 2.12932310e-04, 1.12588956e-04,
#        1.97699065e-08, 4.99900020e-05, 8.90891231e-01, 0.00000000e+00])]
# ['action:', array([3.8186608e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012254e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.97458622e-04, 1.19666274e-04,
# ...

# %% [markdown]
# # 40% interval, 20% Bias

# %%
import Test_offline as To
To.offline_test_out(0.4, 0.2)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99660068e-01, 8.99820036e-05, 1.64332971e-04, 5.28789360e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63872405e-01, 0.00000000e+00])]
# ['action:', array([1.0930979e-05, 1.0000000e+00, 1.0000000e+00, 9.9999988e-01,
#        9.4012624e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99590082e-01, 3.99920016e-05, 2.01018715e-04, 7.56686731e-05,
#        6.45651808e-09, 2.99940012e-05, 9.27484798e-01, 0.00000000e+00])]
# ['action:', array([6.4573446e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012487e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99560088e-01, 1.99960008e-05, 1.95746793e-04, 8.60361558e-05,
#        1.56956631e-08, 4.99900020e-05, 8.91005850e-01, 0.00000000e+00])]
# ['action:', array([3.8267981e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012254e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.78104295e-04, 9.05615273e-05,
# ...

# %% [markdown]
# # 40% interval, 30% Bias

# %%
import Test_offline as To
To.offline_test_out(0.4, 0.3)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99660068e-01, 8.99820036e-05, 1.54040775e-04, 6.58569049e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63872405e-01, 0.00000000e+00])]
# ['action:', array([1.0930979e-05, 1.0000000e+00, 1.0000000e+00, 9.9999988e-01,
#        9.4012624e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99590082e-01, 3.99920016e-05, 1.74097177e-04, 1.01939246e-04,
#        8.04112808e-09, 2.99940012e-05, 9.27448625e-01, 0.00000000e+00])]
# ['action:', array([6.4562796e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012487e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99560088e-01, 1.99960008e-05, 1.57535717e-04, 1.22506795e-04,
#        2.04879100e-08, 4.99900020e-05, 8.90900161e-01, 0.00000000e+00])]
# ['action:', array([3.8247254e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012254e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.33710977e-04, 1.33552405e-04,
# ...
