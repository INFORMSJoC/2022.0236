# %% [markdown]
# # 20% interval, Normal_distribution

# %%
import Test_offline as To
To.offline_test_out(0.2, 'normal20')
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99650070e-01, 8.99820036e-05, 1.68894469e-04, 9.09539040e-05,
#        0.00000000e+00, 9.99800040e-06, 9.60384156e-01, 0.00000000e+00])]
# ['action:', array([2.1656643e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99580084e-01, 3.99920016e-05, 2.29575928e-04, 1.45258785e-04,
#        1.11054929e-08, 2.99940012e-05, 9.20381907e-01, 0.00000000e+00])]
# ['action:', array([1.6142609e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99550090e-01, 1.99960008e-05, 2.38637425e-04, 1.76832661e-04,
#        2.88416243e-08, 5.99880024e-05, 8.80170720e-01, 0.00000000e+00])]
# ['action:', array([1.1968126e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99540092e-01, 9.99800040e-06, 2.24579536e-04, 1.93778642e-04,
# ...

# %% [markdown]
# # 20% interval, Gamma_distribution

# %%
import Test_offline as To
To.offline_test_out(0.2, 'gamma20')
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99650070e-01, 8.99820036e-05, 1.68508435e-04, 8.35583772e-05,
#        0.00000000e+00, 9.99800040e-06, 9.60384156e-01, 0.00000000e+00])]
# ['action:', array([2.1656643e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99580084e-01, 3.99920016e-05, 2.20269401e-04, 1.30153329e-04,
#        1.02024973e-08, 2.99940012e-05, 9.20406329e-01, 0.00000000e+00])]
# ['action:', array([1.6143041e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99550090e-01, 1.99960008e-05, 2.21971869e-04, 1.55738501e-04,
#        2.60942491e-08, 5.99880024e-05, 8.80250269e-01, 0.00000000e+00])]
# ['action:', array([1.1971186e-09, 9.9999976e-01, 1.0000000e+00, 1.0000000e+00,
#        9.9994695e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99540092e-01, 9.99800040e-06, 2.03940411e-04, 1.68655458e-04,
# ...

# %% [markdown]
# # 40% interval, Normal_distribution

# %%
import Test_offline as To
To.offline_test_out(0.4, 'normal40')
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99660068e-01, 8.99820036e-05, 1.56449257e-04, 8.42509041e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63872405e-01, 0.00000000e+00])]
# ['action:', array([1.0930979e-05, 1.0000000e+00, 1.0000000e+00, 9.9999988e-01,
#        9.4012624e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99590082e-01, 3.99920016e-05, 2.08811418e-04, 1.34746318e-04,
#        1.02870354e-08, 2.99940012e-05, 9.27387009e-01, 0.00000000e+00])]
# ['action:', array([6.4489623e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012487e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99560088e-01, 1.99960008e-05, 2.13272178e-04, 1.64121407e-04,
#        2.67395608e-08, 5.99880024e-05, 8.90710124e-01, 0.00000000e+00])]
# ['action:', array([3.8085939e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012260e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.97331341e-04, 1.79772261e-04,
# ...

# %% [markdown]
# # 40% interval, Gamma_distribution

# %%
import Test_offline as To
To.offline_test_out(0.4, 'gamma40')
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99660068e-01, 8.99820036e-05, 1.57000754e-04, 7.89691405e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63872405e-01, 0.00000000e+00])]
# ['action:', array([1.0930979e-05, 1.0000000e+00, 1.0000000e+00, 9.9999988e-01,
#        9.4012624e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99590082e-01, 3.99920016e-05, 2.04681286e-04, 1.24281669e-04,
#        9.64213205e-09, 2.99940012e-05, 9.27403945e-01, 0.00000000e+00])]
# ['action:', array([6.4506298e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012487e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99560088e-01, 1.99960008e-05, 2.05403455e-04, 1.49786021e-04,
#        2.48169239e-08, 5.99880024e-05, 8.90763798e-01, 0.00000000e+00])]
# ['action:', array([3.8122932e-06, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        9.4012254e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.87688865e-04, 1.62970524e-04,
# ...
