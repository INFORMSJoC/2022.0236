# %%
from Train_main import *
from Offline_test import *

# %%
offline_stage(20, 2.7e6, 200)
offline_test(20, 2.7e6)
# Out:
# [0, 0, -112196703.60942031, 181139.7071723049, 771631.5699562072]
# [0, 1, -111791713.59876029, 180308.07138807914, 768430.3007948461]
# [0, 2, -112159254.72108065, 180633.5910306847, 771413.2977288546]
# [0, 3, -110906566.10461666, 188326.78719971824, 750841.6620404505]
# [0, 4, -111888892.80632202, 180644.78157960862, 768897.511451985]
# [0, 5, -111939007.45231152, 179986.2371418589, 769755.372874674]
# [0, 6, -111984667.05350676, 179619.82197199913, 770926.3943092303]
# [0, 7, -110621804.43632835, 188890.0960782854, 748280.4380586252]
# [0, 8, -112219846.33746752, 181063.34281146812, 772320.6625089205]
# [0, 9, -112196703.60942031, 181139.7071723049, 771631.5699562072]
# [0, 10, -111791713.59876029, 180308.07138807914, 768430.3007948461]
# [0, 11, -112159254.72108065, 180633.5910306847, 771413.2977288546]
# [0, 12, -110906566.10461666, 188326.78719971824, 750841.6620404505]
# [0, 13, -111888892.80632202, 180644.78157960862, 768897.511451985]
# ...
