# %% [markdown]
# # 20% interval, 10% bias

# %%
import Test_main as Tm
Tm.online_test_out(0.2, 0.1)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99650070e-01, 8.99820036e-05, 1.71930810e-04, 6.89372369e-05,
#        0.00000000e+00, 9.99800040e-06, 9.60428973e-01, 0.00000000e+00])]
# ['action:', array([3.8700341e-04, 9.9997151e-01, 9.9999654e-01, 9.9999654e-01,
#        9.9902225e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99590082e-01, 3.99920016e-05, 2.14367908e-04, 1.02042937e-04,
#        8.41730091e-09, 2.99940012e-05, 9.20537969e-01, 0.00000000e+00])]
# ['action:', array([1.1528233e-07, 9.9999905e-01, 9.9999952e-01, 9.9999976e-01,
#        9.9926263e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99560088e-01, 1.99960008e-05, 2.10118082e-04, 1.18393161e-04,
#        2.08768149e-08, 5.99880024e-05, 8.80509742e-01, 0.00000000e+00])]
# ['action:', array([5.6790380e-08, 9.9999928e-01, 9.9999976e-01, 9.9999988e-01,
#        9.9939978e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.90723329e-04, 1.26016669e-04,
# ...

# %% [markdown]
# # 20% interval, 20% bias

# %%
import Test_main as Tm
Tm.online_test_out(0.2, 0.2)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99650070e-01, 8.99820036e-05, 1.73429853e-04, 6.49981725e-05,
#        0.00000000e+00, 9.99800040e-06, 9.60428973e-01, 0.00000000e+00])]
# ['action:', array([3.8700341e-04, 9.9997151e-01, 9.9999654e-01, 9.9999654e-01,
#        9.9902225e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99590082e-01, 3.99920016e-05, 2.15562180e-04, 9.43691295e-05,
#        7.93633748e-09, 2.99940012e-05, 9.20549927e-01, 0.00000000e+00])]
# ['action:', array([1.1528342e-07, 9.9999905e-01, 9.9999952e-01, 9.9999976e-01,
#        9.9926263e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99560088e-01, 1.99960008e-05, 2.11483895e-04, 1.08026665e-04,
#        1.94588742e-08, 4.99900020e-05, 8.80546059e-01, 0.00000000e+00])]
# ['action:', array([5.6798495e-08, 9.9999928e-01, 9.9999976e-01, 9.9999988e-01,
#        9.9939978e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.92714985e-04, 1.13961250e-04,
# ...

# %% [markdown]
# # 20% interval, 30% bias

# %%
import Test_main as Tm
Tm.online_test_out(0.2, 0.3)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99650070e-01, 8.99820036e-05, 1.74627924e-04, 5.28787235e-05,
#        0.00000000e+00, 9.99800040e-06, 9.60428973e-01, 0.00000000e+00])]
# ['action:', array([3.8700341e-04, 9.9997151e-01, 9.9999654e-01, 9.9999654e-01,
#        9.9902225e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99590082e-01, 3.99920016e-05, 2.04633502e-04, 7.36320525e-05,
#        6.45654145e-09, 2.99940012e-05, 9.20588821e-01, 0.00000000e+00])]
# ['action:', array([1.1528882e-07, 9.9999905e-01, 9.9999952e-01, 9.9999976e-01,
#        9.9926263e-01], dtype=float32)]
# ['time:', 2, 'state:', array([9.99560088e-01, 1.99960008e-05, 1.94342257e-04, 8.27316228e-05,
#        1.54470666e-08, 4.99900020e-05, 8.80659494e-01, 0.00000000e+00])]
# ['action:', array([5.6828952e-08, 9.9999928e-01, 9.9999976e-01, 9.9999988e-01,
#        9.9939978e-01], dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.74482884e-04, 8.67189212e-05,
# ...

# %% [markdown]
# # 40% interval, 10% bias

# %%
import Test_main as Tm
Tm.online_test_out(0.4, 0.1)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99670066e-01, 8.99820036e-05, 1.64944992e-04, 6.49984413e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63302898e-01, 0.00000000e+00])]
# ['action:', array([9.528602e-06, 1.000000e+00, 1.000000e+00, 9.999999e-01,
#        9.501462e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99600080e-01, 3.99920016e-05, 2.15044788e-04, 9.64826419e-05,
#        7.93634756e-09, 3.99920016e-05, 9.23741789e-01, 0.00000000e+00])]
# ['action:', array([0.00394454, 0.9999994 , 1.        , 1.        , 0.9921875 ],
#       dtype=float32)]
# ['time:', 2, 'state:', array([9.99570086e-01, 1.99960008e-05, 2.13808360e-04, 1.11034705e-04,
#        1.97169794e-08, 6.99860028e-05, 8.84609718e-01, 0.00000000e+00])]
# ['action:', array([0.00149975, 0.9999989 , 1.        , 1.        , 0.983943  ],
#       dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.96074078e-04, 1.17355971e-04,
# ...

# %% [markdown]
# # 40% interval, 20% bias

# %%
import Test_main as Tm
Tm.online_test_out(0.4, 0.2)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99670066e-01, 8.99820036e-05, 1.66084448e-04, 5.28789368e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63302898e-01, 0.00000000e+00])]
# ['action:', array([9.528602e-06, 1.000000e+00, 1.000000e+00, 9.999999e-01,
#        9.501462e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99600080e-01, 3.99920016e-05, 2.04207402e-04, 7.53214740e-05,
#        6.45654900e-09, 3.99920016e-05, 9.23780518e-01, 0.00000000e+00])]
# ['action:', array([0.00395183, 0.9999994 , 1.        , 1.        , 0.9921875 ],
#       dtype=float32)]
# ['time:', 2, 'state:', array([9.99570086e-01, 1.99960008e-05, 1.96276864e-04, 8.49638531e-05,
#        1.56533800e-08, 6.99860028e-05, 8.84724062e-01, 0.00000000e+00])]
# ['action:', array([0.00150852, 0.9999989 , 1.        , 1.        , 0.98394287],
#       dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.77071254e-04, 8.91070911e-05,
# ...

# %% [markdown]
# # 40% interval, 30% bias

# %%
import Test_main as Tm
Tm.online_test_out(0.4, 0.3)
# Out:
# model have been loaded
# ['time:', 0, 'state:', array([9.99670066e-01, 8.99820036e-05, 1.55682556e-04, 6.58569056e-05,
#        0.00000000e+00, 9.99800040e-06, 9.63302898e-01, 0.00000000e+00])]
# ['action:', array([9.528602e-06, 1.000000e+00, 1.000000e+00, 9.999999e-01,
#        9.501462e-01], dtype=float32)]
# ['time:', 1, 'state:', array([9.99600080e-01, 3.99920016e-05, 1.76758827e-04, 1.01652223e-04,
#        8.04116656e-09, 3.99920016e-05, 9.23744523e-01, 0.00000000e+00])]
# ['action:', array([0.00395009, 0.9999994 , 1.        , 1.        , 0.9921875 ],
#       dtype=float32)]
# ['time:', 2, 'state:', array([9.99570086e-01, 1.99960008e-05, 1.57921612e-04, 1.21649458e-04,
#        2.04529977e-08, 6.99860028e-05, 8.84599678e-01, 0.00000000e+00])]
# ['action:', array([0.00146606, 0.99999905, 1.        , 1.        , 0.98428637],
#       dtype=float32)]
# ['time:', 3, 'state:', array([9.99550090e-01, 9.99800040e-06, 1.32975520e-04, 1.32352308e-04,
# ...
